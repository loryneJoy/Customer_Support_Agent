# %% [markdown]
# # Simple Customer Support Chatbot Demo\nThis notebook demonstrates the classification logic and sample inputs/outputs.

# %%
from customer_support_agent import chat_once\nsamples = [\n  'How can I update my payment method?',\n  'My internet is not working and shows an error code 500',\n  'What are your business hours and where are you located?',\n  'I am very angry about a charge I did not make',\n  'This is nonsense, nothing works'\n]\nfor s in samples:\n    out = chat_once(s)\n    print('Question:', s)\n    print('Category:', out['category'])\n    print('Response:', out['response'])\n    print('Escalate?', out['escalate'])\n    print('-'*50)\n
